# %%
import pandas as pd
import numpy as np
import os
pd.options.display.max_columns = 999
import os.path
from math import log2

# %%
os.chdir(r'C:\Users\Inhen\Desktop\stormdata\csv')

# %%
file_ls=os.listdir(r'C:\Users\Inhen\Desktop\stormdata\csv')

# %%
df0=pd.read_csv(file_ls[0]).values

for csvname in file_ls:
    df1=pd.read_csv(csvname).values
    df0=np.vstack((df0,df1))
# Out:
# C:\Software\PythonAnaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Software\PythonAnaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Software\PythonAnaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (29,34,35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
full_df=pd.DataFrame(df0)

# %%
full_df.head()
# Out:
#   BEGIN_YEARMONTH BEGIN_DAY BEGIN_TIME END_YEARMONTH END_DAY END_TIME  \
# 0          195509        22       1610        195509      22     1610
# 1          195505        28        800        195505      28      800
# 2          195506        10       1500        195506      10     1500
# 3          195507        19       1330        195507      19     1330
# 4          195507        28       1500        195507      28     1500
#
#   EPISODE_ID  EVENT_ID     STATE STATE_FIPS     ...     END_RANGE END_AZIMUTH  \
# 0        NaN  10063685  MISSOURI         29     ...             0         NaN
# 1        NaN  10039446  MICHIGAN         26     ...             0         NaN
# 2        NaN   9976778   ALABAMA          1     ...             0         NaN
# 3        NaN   9976779   ALABAMA          1     ...             0         NaN
# 4        NaN   9976780   ALABAMA          1     ...             0         NaN
#
#   END_LOCATION BEGIN_LAT BEGIN_LON END_LAT END_LON EPISODE_NARRATIVE  \
# ...

# %%
df2.columns
# Out:
# 'BEGIN_YEARMONTH'

# %%
full_df.rename(columns={i:df2.columns[i] for i in range(len(df2.columns))}, 
                 inplace=True)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1464121 entries, 0 to 1464120
# Data columns (total 51 columns):
# BEGIN_YEARMONTH       1464121 non-null object
# BEGIN_DAY             1464121 non-null object
# BEGIN_TIME            1464121 non-null object
# END_YEARMONTH         1464121 non-null object
# END_DAY               1464121 non-null object
# END_TIME              1464121 non-null object
# EPISODE_ID            1239697 non-null object
# EVENT_ID              1464121 non-null object
# STATE                 1464120 non-null object
# STATE_FIPS            1464120 non-null object
# YEAR                  1464121 non-null object
# MONTH_NAME            1464121 non-null object
# EVENT_TYPE            1464121 non-null object
# CZ_TYPE               1464121 non-null object
# CZ_FIPS               1464121 non-null object
# CZ_NAME               1462536 non-null object
# WFO                   1339700 non-null object
# BEGIN_DATE_TIME       1464121 non-null object
# ...

# %%
full_df.to_csv('1955_2017.csv')

# %%
full_df=pd.read_csv('1955_2017.csv')
# Out:
# C:\Software\PythonAnaconda\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (17,26,27,29,30,35,36,38,40,41,43,44,49,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
full_df.head()
# Out:
#    Unnamed: 0  BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0           0           195509         22        1610         195509       22
# 1           1           195505         28         800         195505       28
# 2           2           195506         10        1500         195506       10
# 3           3           195507         19        1330         195507       19
# 4           4           195507         28        1500         195507       28
#
#    END_TIME  EPISODE_ID  EVENT_ID     STATE  STATE_FIPS  YEAR MONTH_NAME  \
# 0      1610         NaN  10063685  MISSOURI        29.0  1955  September
# 1       800         NaN  10039446  MICHIGAN        26.0  1955        May
# 2      1500         NaN   9976778   ALABAMA         1.0  1955       June
# 3      1330         NaN   9976779   ALABAMA         1.0  1955       July
# 4      1500         NaN   9976780   ALABAMA         1.0  1955       July
#
# ...

# %%
full_df["year"]=full_df["BEGIN_YEARMONTH"].apply(lambda x:int(x/100))

# %%
full_df[""]

# %%
full_df.groupby(["EVENT_TYPE","year"]).sum()
# Out:
#                             Unnamed: 0  BEGIN_YEARMONTH  BEGIN_DAY  \
# EVENT_TYPE            year
# Astronomical Low Tide 1997     1484602           998515         30
#                       2007    49136606         12242844        686
#                       2008    38173669          8835367        549
#                       2009    38194978          8237194        604
#                       2010    39736393          8040133        502
#                       2011    29811415          5630861        536
#                       2012    57930339         10261494       1161
#                       2013    33937204          5636549        441
#                       2014    78008665         12486912        858
#                       2015   105367092         16120197       1171
#                       2016    63552750          9273987        719
#                       2017    18462615          2622142        267
# Avalanche             1996     1692596          1397237        101
# ...

# %%
after2000_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1051786 entries, 412335 to 1464120
# Data columns (total 53 columns):
# Unnamed: 0            1051786 non-null int64
# BEGIN_YEARMONTH       1051786 non-null int64
# BEGIN_DAY             1051786 non-null int64
# BEGIN_TIME            1051786 non-null int64
# END_YEARMONTH         1051786 non-null int64
# END_DAY               1051786 non-null int64
# END_TIME              1051786 non-null int64
# EPISODE_ID            1051786 non-null float64
# EVENT_ID              1051786 non-null int64
# STATE                 1051785 non-null object
# STATE_FIPS            1051785 non-null float64
# YEAR                  1051786 non-null int64
# MONTH_NAME            1051786 non-null object
# EVENT_TYPE            1051786 non-null object
# CZ_TYPE               1051786 non-null object
# CZ_FIPS               1051786 non-null int64
# CZ_NAME               1051786 non-null object
# WFO                   1051786 non-null object
# ...

# %%
after2000_df=full_df[full_df["year"]>1999]

# %%
list(after2000_df[['year','DEATHS_DIRECT']].groupby('year').sum()['DEATHS_DIRECT'])
# Out:
# [477,
#  469,
#  498,
#  443,
#  370,
#  1451,
#  607,
#  523,
#  571,
#  374,
#  491,
#  1096,
#  537,
#  448,
#  388,
#  536,
#  463,
#  543]

# %%
after2000_df[after2000_df['year']==2005]
# Out:
#         Unnamed: 0  BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  \
# 669518      669518           200501          4        1800         200501
# 669519      669519           200501          4        1800         200501
# 669520      669520           200501          1         500         200501
# 669521      669521           200501          1         500         200501
# 669522      669522           200501          8        1600         200501
# 669523      669523           200501          6         500         200501
# 669524      669524           200501         23         500         200501
# 669525      669525           200501         23         200         200501
# 669526      669526           200501         22        2250         200501
# 669527      669527           200501         23         300         200501
# 669528      669528           200501          6         500         200501
# 669529      669529           200501         29        1200         200501
# ...

# %%
after2000_df.groupby(["year"]).sum()
# Out:
#        Unnamed: 0  BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  \
# year
# 2000  22796644366      10401730359     780606    66044948    10401730459
# 2001  23889073625       9780181368     729182    63500076     9780181368
# 2002  27438433692      10197699809     755331    65935926    10197699809
# 2003  31277428758      10607405071     742581    71461033    10607405171
# 2004  33715391017      10503082791     827963    71322446    10503082791
# 2005  37594580868      10822522536     814129    71844056    10822524836
# 2006  42395513400      11314180105     840848    75161776    11314180105
# 2007  47762605485      11843672246     825264    73269361    11843672246
# 2008  62255548215      14295371047    1052055    92545609    14295371047
# 2009  53884811915      11531604953     854781    75545431    11531604954
# 2010  62734507374      12623999395     997401    81443759    12623999395
# 2011  84614794531      15905647907    1167853   100143534    15905647907
# ...

# %%
heat_df=full_df[full_df["EVENT_TYPE"]=='Cold/Wind Chill']

# %%
heat_df=full_df[full_df["EVENT_TYPE"]=='Excessive Heat']

# %%
heat_df.groupby(["year"]).count()['INJURIES_DIRECT']
# Out:
# year
# 2000     378
# 2001     100
# 2002     243
# 2007     488
# 2008     147
# 2009     146
# 2010    1240
# 2011    1698
# 2012    1156
# 2013     208
# 2014      83
# 2015     325
# 2016     555
# 2017     260
# Name: INJURIES_DIRECT, dtype: int64

# %%
list(heat_df.groupby(["year"]).count()['INJURIES_DIRECT'])
# Out:
# [378, 100, 243, 488, 147, 146, 1240, 1698, 1156, 208, 83, 325, 555, 260]

# %%
list(heat_df.groupby(["year"]).count()['DEATHS_DIRECT'][4:])
# Out:
# [236,
#  127,
#  154,
#  390,
#  1064,
#  583,
#  345,
#  454,
#  523,
#  436,
#  344,
#  195,
#  56,
#  459,
#  1146,
#  925,
#  181,
#  285]

# %%
list(after2000_df.groupby(["year"])['END_DAY'].count())
# Out:
# [52007,
#  48875,
#  50936,
#  52956,
#  52409,
#  53976,
#  56400,
#  59010,
#  71190,
#  57398,
#  62804,
#  79091,
#  64503,
#  59985,
#  59465,
#  57788,
#  56003,
#  56990]

# %%
list(after2000_df.groupby(["year"]).sum()['DEATHS_DIRECT'])
# Out:
# [477,
#  469,
#  498,
#  443,
#  370,
#  1451,
#  607,
#  523,
#  571,
#  374,
#  491,
#  1096,
#  537,
#  448,
#  388,
#  536,
#  463,
#  543]

# %%
totalevent=list(full_df.groupby(["year"]).count()['Unnamed: 0'])

# %%
[log2(x) for x in totalevent]
# Out:
# [11.46454575033394,
#  10.733862719678543,
#  11.092757140919852,
#  11.11178773580101,
#  10.824163209744158,
#  10.925554439873554,
#  11.133142212400601,
#  11.222191138456333,
#  10.94251450533924,
#  11.197216693110052,
#  11.469133019829592,
#  11.221587121264806,
#  11.39231742277876,
#  11.693486957499324,
#  11.514714054138487,
#  11.650603022215309,
#  11.761135649828645,
#  11.084144010615145,
#  12.120561896442904,
#  12.392049039364185,
#  12.280480810318373,
#  11.879583249612784,
#  11.86418614465428,
#  11.836444911341369,
#  12.06305796362349,
#  12.583082767502933,
#  12.141149198437516,
#  12.798876768133299,
#  13.022714573044759,
#  12.840581250560753,
#  12.961992230928898,
#  13.090939415984376,
#  12.82515755470108,
#  13.345266626007538,
#  13.417984334068308,
#  13.611485943240922,
#  13.724300673209568,
#  13.080817527608327,
#  13.931753222471858,
#  14.320589035863657,
#  15.567510510372582,
#  15.35779252537568,
#  15.637445644657681,
# ...

# %%
full_df.head()
# Out:
#    Unnamed: 0  BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0           0           195509         22        1610         195509       22
# 1           1           195505         28         800         195505       28
# 2           2           195506         10        1500         195506       10
# 3           3           195507         19        1330         195507       19
# 4           4           195507         28        1500         195507       28
#
#    END_TIME  EPISODE_ID  EVENT_ID     STATE     ...      END_RANGE  \
# 0      1610         NaN  10063685  MISSOURI     ...            0.0
# 1       800         NaN  10039446  MICHIGAN     ...            0.0
# 2      1500         NaN   9976778   ALABAMA     ...            0.0
# 3      1330         NaN   9976779   ALABAMA     ...            0.0
# 4      1500         NaN   9976780   ALABAMA     ...            0.0
#
#    END_AZIMUTH END_LOCATION BEGIN_LAT BEGIN_LON  END_LAT END_LON  \
# ...

# %%
full_df['BEGIN_YEARMONTH']
# Out:
# 0          195509
# 1          195505
# 2          195506
# 3          195507
# 4          195507
# 5          195510
# 6          195510
# 7          195510
# 8          195510
# 9          195510
# 10         195510
# 11         195504
# 12         195509
# 13         195511
# 14         195506
# 15         195505
# 16         195503
# 17         195505
# 18         195505
# 19         195507
# 20         195506
# 21         195503
# 22         195503
# 23         195503
# 24         195503
# 25         195503
# 26         195503
# 27         195503
# 28         195503
# 29         195503
#             ...
# 1464091    201707
# 1464092    201707
# 1464093    201707
# 1464094    201707
# 1464095    201707
# 1464096    201707
# 1464097    201706
# 1464098    201706
# 1464099    201706
# 1464100    201707
# 1464101    201707
# 1464102    201707
# 1464103    201707
# 1464104    201704
# 1464105    201703
# 1464106    201706
# 1464107    201706
# 1464108    201707
# 1464109    201707
# ...

# %%
df0=pd.DataFrame()

# %%
df1=pd.read_csv('StormEvents_details-ftp_v1.0_d1955_c20160223.csv')

# %%
df2.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='object')

# %%
df2=pd.read_csv('StormEvents_details-ftp_v1.0_d1956_c20170717.csv')

# %%
df1.values
# Out:
# array([[195509, 22, 1610, ..., nan, nan, 'PUB'],
#        [195505, 28, 800, ..., nan, nan, 'PUB'],
#        [195506, 10, 1500, ..., nan, nan, 'PUB'],
#        ...,
#        [195505, 25, 1120, ..., nan, nan, 'PUB'],
#        [195505, 25, 1720, ..., nan, nan, 'PUB'],
#        [195511, 15, 1517, ..., nan, nan, 'PUB']], dtype=object)

# %%
len(np.vstack((df1.values,df0.values)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-e8e4aa498e65> in <module>()
# ----> 1 len(np.vstack((df1.values,df0.values)))
#
# C:\Software\PythonAnaconda\envs\py36\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
df1.values+df2.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-bcb2247f9d7f> in <module>()
# ----> 1 df1.values+df2.values
#
# ValueError: operands could not be broadcast together with shapes (1413,51) (1703,51)

# %%
full_df['BEGIN_YEARMONTH']=full_df['BEGIN_YEARMONTH'].astype(int)

# %%
full_df[full_df['BEGIN_YEARMONTH']>201100].to_csv('2011upto.csv')
